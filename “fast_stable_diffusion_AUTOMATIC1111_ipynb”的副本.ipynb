# %% [markdown]
# <a href="https://colab.research.google.com/github/zhujinhuant/BaiduImageDownload/blob/master/%E2%80%9Cfast_stable_diffusion_AUTOMATIC1111_ipynb%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook From https://github.com/TheLastBen/fast-stable-diffusion, if you encounter any issues, feel free to discuss them.** [Support](https://ko-fi.com/thelastben)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#@markdown # Install/Update AUTOMATIC1111 repo
from IPython.utils import capture
from IPython.display import clear_output
from subprocess import getoutput
import ipywidgets as widgets
import sys
import fileinput
import os
import time

if not os.path.exists("/content/gdrive/MyDrive/"):
  print('[1;31mGdrive not connected, using colab storage ...')
  time.sleep(4)
  # !mkdir -p /content/gdrive/MyDrive/
with capture.capture_output() as cap:
  def inf(msg, style, wdth): inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=widgets.Layout(min_width=wdth));display(inf)
  fgitclone = "git clone --depth 1"
  # %mkdir -p /content/gdrive/MyDrive/sd
  # %cd /content/gdrive/MyDrive/sd
  # !$fgitclone -q --branch master https://github.com/AUTOMATIC1111/stable-diffusion-webui
  # !mkdir -p /content/gdrive/MyDrive/sd/stable-diffusion-webui/cache/huggingface
  # !ln -s /content/gdrive/MyDrive/sd/stable-diffusion-webui/cache/huggingface /root/.cache/

with capture.capture_output() as cap:
  # %cd /content/gdrive/MyDrive/sd/stable-diffusion-webui/
  # !git reset --hard
  time.sleep(1)
  # !rm webui.sh
print('[1;32m')
# !git pull
clear_output()
inf('\u2714 Done','success', '50px')
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # Requirements

print('[1;32mInstalling requirements...')

with capture.capture_output() as cap:
  # %cd /content/ 
  # !wget -q -i https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/Dependencies/A1111.txt
  # !dpkg -i *.deb
  if not os.path.exists('/content/gdrive/MyDrive/sd/stablediffusion'):
    # !tar -C / --zstd -xf sd.tar.zst 
  # !tar -C / --zstd -xf A1111_dep.tar.zst
  # !rm *.deb | rm *.zst | rm *.txt
  # %env LD_PRELOAD=libtcmalloc.so
  os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

clear_output()
inf('\u2714 Done','success', '50px')
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # Model Download/Load
Model_Version = "V2.1-512px" #@param [ "1.5", "v1.5 Inpainting ", "V2.1-512px", "V2.1-768px"]

Redownload_the_original_model = True #@param {type:"boolean"}

def rmv():
  # !wget -q -O /content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/precompiled/README.md
  # !mv /content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt /content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/trashfile.f
  time.sleep(2)
  # !rm /content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/trashfile.f
  clear_output()

if Redownload_the_original_model:
  with capture.capture_output() as cap:
    rmv()

#@markdown Or
Path_to_MODEL = "" #@param {type:"string"}
#@markdown - Insert the full path of your trained model or to a folder containing multiple models.

#@markdown Or
MODEL_LINK = "" #@param {type:"string"}
safetensors = True #@param {type:"boolean"}
Use_temp_storage = False #@param {type:"boolean"}



def newmdl():

    if not os.path.exists('/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt'):
      # %cd /content/
      clear_output()
      # !git init
      # !git lfs install --system --skip-repo
      # !$fgitclone --branch fp16 "https://huggingface.co/runwayml/stable-diffusion-v1-5"
      if os.path.exists('/content/stable-diffusion-v1-5/unet/diffusion_pytorch_model.bin'):
        # !wget -q -O stable-diffusion-v1-5/vae/diffusion_pytorch_model.bin https://huggingface.co/stabilityai/sd-vae-ft-mse/resolve/main/diffusion_pytorch_model.bin
        # !wget -O convertosd.py https://github.com/TheLastBen/fast-stable-diffusion/raw/main/Dreambooth/convertosd.py
        # !sed -i '201s@.*@    model_path = "/content/stable-diffusion-v1-5"@' /content/convertosd.py
        # !sed -i '202s@.*@    checkpoint_path= "/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt"@' /content/convertosd.py
        clear_output()       
        # !python /content/convertosd.py
        # !rm /content/convertosd.py
        if os.path.exists('/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt'):
          model='/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt'
          clear_output()
          inf('\u2714 Done','success', '50px')
        else:
          inf('\u2718 Something went wrong, try again','danger', "250px")
      else:
        inf('\u2718 Something went wrong','danger', "200px")

    else:
      model='/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt'
      clear_output()
      inf('\u2714 Model already exists, check the box "Redownload_the_original_model" to redownload/download the V1.5','primary', '700px')

    if os.path.exists('/content/.git'):
      # !rm -r /content/.git

    if os.path.exists('/content/stable-diffusion-v1-5'):
      # !rm -r /content/stable-diffusion-v1-5

    return model

def V2():

    if not os.path.exists('/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt'):
      # %cd /content/
      clear_output()
      # !mkdir "/content/stable-diffusion-V2"
      # %cd "/content/stable-diffusion-V2"
      # !git init
      # !git lfs install --system --skip-repo
      if Model_Version == "V2.1-768px":
        # !git remote add -f origin  "https://huggingface.co/stabilityai/stable-diffusion-2-1"
      elif Model_Version == "V2.1-512px":
        # !git remote add -f origin  "https://huggingface.co/stabilityai/stable-diffusion-2-1-base"
      # !git config core.sparsecheckout true
      # !echo -e "scheduler\ntext_encoder\ntokenizer\nunet\nvae\nfeature_extractor\nmodel_index.json\n!*.safetensors" > .git/info/sparse-checkout
      # !git pull origin fp16
      # %cd /content
      # !wget -O convertosdv2.py https://github.com/TheLastBen/fast-stable-diffusion/raw/main/Dreambooth/convertosdv2.py
      clear_output()
      # !python /content/convertosdv2.py --fp16 /content/stable-diffusion-V2 /content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt
      # !rm /content/convertosdv2.py
      if os.path.exists('/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt'):
        model='/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt'
        clear_output()
        inf('\u2714 Done','success', '50px')
      else:
        inf('\u2718 Something went wrong, try again','danger', "250px")

    else:
      model='/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/model.ckpt'
      clear_output()
      inf('\u2714 Model already exists, check the box "Redownload_the_original_model" to redownload/download the V2','primary', '700px')

    if os.path.exists('/content/.git'):
      # !rm -r /content/.git
      # !rm -r /content/convertosdv2.py
    if os.path.exists('/content/stable-diffusion-V2'):
      # !rm -r /content/stable-diffusion-V2

    return model

def inpmdl():

    if not os.path.exists('/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt'):
      # %cd /content/
      clear_output()
      # !git init
      # !git lfs install --system --skip-repo
      # !$fgitclone --branch fp16 "https://huggingface.co/runwayml/stable-diffusion-inpainting"
      if os.path.exists('/content/stable-diffusion-inpainting'):
        # !$fgitclone "https://huggingface.co/stabilityai/sd-vae-ft-mse"
        # !rm -r /content/stable-diffusion-inpainting/vae
        # !mv /content/sd-vae-ft-mse /content/stable-diffusion-inpainting/vae        
        # !wget -O convertosd.py https://github.com/TheLastBen/fast-stable-diffusion/raw/main/Dreambooth/convertosd.py
        # !sed -i '201s@.*@    model_path = "/content/stable-diffusion-inpainting"@' /content/convertosd.py
        # !sed -i '202s@.*@    checkpoint_path= "/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt"@' /content/convertosd.py
        clear_output()       
        # !python /content/convertosd.py
        # !rm /content/convertosd.py
        if os.path.exists('/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt'):
          model='/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt'
          clear_output()
          inf('\u2714 Done','success', '50px')
        else:
          inf('\u2718 Something went wrong, try again','danger', "250px")
      else:
        inf('\u2718 Something went wrong','danger', "200px")


    else:
      model='/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt'
      clear_output()
      inf('\u2714 inpainting model already exists','primary', '250px')

    if os.path.exists('/content/.git'):
      # !rm -r /content/.git

    if os.path.exists('/content/stable-diffusion-inpainting'):
      # !rm -r /content/stable-diffusion-inpainting

    return model

if (Path_to_MODEL !=''):
  if os.path.exists(str(Path_to_MODEL)):
    inf('\u2714 Using the trained model.','success', '200px')

  else:
      while not os.path.exists(str(Path_to_MODEL)):
        inf('\u2718 Wrong path, use the colab file explorer to copy the path : ','danger', "400px")
        Path_to_MODEL=input()
      if os.path.exists(str(Path_to_MODEL)):
        inf('\u2714 Using the trained model.','success', '200px')

  model=Path_to_MODEL

elif MODEL_LINK != "":
  gdrv="/content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion"
  tmp="/content"
  pth=tmp if Use_temp_storage else gdrv
  # %cd $pth
  clear_output()
  if not safetensors:
    modelname="model.ckpt"
  else:
    modelname="model.safetensors"
  # !gdown --fuzzy -O $modelname $MODEL_LINK
  if os.path.exists(f'{pth}/{modelname}') and os.path.getsize(f'{pth}/{modelname}') > 1810671599:    
      model=f'{pth}/{modelname}'
      clear_output()
      inf('\u2714 Model downloaded, using the trained model.','success', '350px')
  else:
    if Use_temp_storage:
      # !rm $pth/$modelname
    else:
      rmv()
    inf('\u2718 Wrong link, check that the link is valid','danger', "300px")


elif Model_Version=="1.5":
  model=newmdl()

elif Model_Version=="V2.1-512px" or Model_Version=="V2.1-768px":
  model=V2()

else:
   model=inpmdl()
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %%
#@markdown # ControlNet
from torch.hub import download_url_to_file
from urllib.parse import urlparse

Model = "All" #@param [ "All", "Canny", "Depth", "HED", "MLSD", "Normal", "OpenPose", "Scribble", "Seg", "T2iadapter_Models"]

#@markdown - Download/update ControlNet extension and its models.

def download(url, model_dir):

    filename = os.path.basename(urlparse(url).path)
    pth = os.path.abspath(os.path.join(model_dir, filename))
    if not os.path.exists(pth):
        print('Downloading: '+os.path.basename(url))
        download_url_to_file(url, pth, hash_prefix=None, progress=True)
    else:
      print(f"[1;32mThe model {filename} already exists[0m")

Canny='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_canny-fp16.safetensors'
Depth='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_depth-fp16.safetensors'
HED='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_hed-fp16.safetensors'
MLSD='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_mlsd-fp16.safetensors'
Normal='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_normal-fp16.safetensors'
OpenPose='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_openpose-fp16.safetensors'
Scribble='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_scribble-fp16.safetensors'
Seg='https://huggingface.co/webui/ControlNet-modules-safetensors/resolve/main/control_seg-fp16.safetensors'


with capture.capture_output() as cap:
  # %cd /content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions
  if not os.path.exists("sd-webui-controlnet"):
    # !git clone https://github.com/Mikubill/sd-webui-controlnet.git
    # %cd /content
  else:
    # %cd sd-webui-controlnet
    # !git pull
    # %cd /content

# !cp /content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models/*.yaml /content/gdrive/MyDrive/sd/stable-diffusion-webui/models
mdldir="/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/models"

# !wget -q -O CN_models.txt https://github.com/TheLastBen/fast-stable-diffusion/raw/main/AUTOMATIC1111_files/CN_models.txt
with open("CN_models.txt", 'r') as f:
  mdllnk = f.read().splitlines()
# !rm CN_models.txt

if Model == "All": 
  for lnk in mdllnk:
      download(lnk, mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')

elif Model == "T2iadapter_Models":
  mdllnk=list(filter(lambda x: 't2i' in x, mdllnk))
  for lnk in mdllnk:
      download(lnk, mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')

else:
  download(globals()[Model], mdldir)
  clear_output()
  inf('\u2714 Done','success', '50px')

# %%
# %cd /content/gdrive/MyDrive/sd/stable-diffusion-webui
! ls models/Stable-diffusion
# !wget https://huggingface.co/wavymulder/modelshoot/resolve/main/modelshoot-1.0.ckpt -O models/Stable-diffusion/modelshoot-1.0.ckpt
# !wget https://huggingface.co/hassanblend/hassanblend1.4/resolve/main/HassanBlend1.4.ckpt -O models/Stable-diffusion/HassanBlend1.4.ckpt
# !wget https://huggingface.co/xiaolxl/GuoFeng3/resolve/main/GuoFeng3.ckpt  -O models/Stable-diffusion/GuoFeng3.ckpt
# !wget https://huggingface.co/swl-models/chilloutmix-ni/resolve/main/chilloutmix-Ni.safetensors  -O models/Stable-diffusion/chilloutmix-Ni.safetensors
# !wget https://civitai.com/api/download/models/15640 -O models/Stable-diffusion/uberRealisticPornMerge_urpmv13.safetensors

# !wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_canny.pth -O models/Stable-diffusion/control_sd15_canny.pth
# !wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_depth.pth
# !wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_hed.pth
# !wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_mlsd.pth
# !wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_normal.pth
# !wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_openpose.pth
# !wget https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15_scribble.pth
# Out:
# /content/gdrive/MyDrive/sd/stable-diffusion-webui
#  chilloutmix-Ni.safetensors   model.ckpt
#  control_sd15_canny.pth      'Put Stable Diffusion checkpoints here.txt'
#  GuoFeng3.ckpt		      uberRealisticPornMerge_urpmv13.safetensors
#  HassanBlend1.4.ckpt
# --2023-03-18 11:32:25--  https://huggingface.co/lllyasviel/ControlNet/resolve/main/models/control_sd15
response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27control_sd15_normal.pth%3B+filename%3D%22control_sd15_normal.pth%22%3B&Expires=1679398352&Policy=__&Signature=sw4hu2h0FSsS3qjb5b3%7E%7EMTyqFMD5G-SC4Eufk-t0hSPUOwm4zha9y41n0bXt8FFWwfymcT3Uf4RuW4KXgZ3VvoLHmxF%7E7oKOrZ3MWj90ptQ2D6XFv-3fmSXdKx5oBOAn7mXtjYjASXoGXv8DEyg20WUSSGkezLyLVfZRizXsOxbgX4h4bosnGyaaPYnJDo0RFZsV%7EXUx3fmHj4huWbBo1778jdDwNVKLDM8R20f%7E03FxSA1xatD4ZsI279gVESIEuwPBTU07oVfK8a7A3fbDKdtWp7k9OaAt-aeRUQoGb4lBlyKJ-O4RSCO5Qd9zHiC%7EXcebBPYoV4Fs7Eybis51w__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.65.229.35, 18.65.229.16, 18.65.229.83, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.65.229.35|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5710754879 (5.3G) [binary/octet-stream]
# Saving to: ‘control_sd15_normal.pth.1’
#
#   control_sd15_norm   0%[                    ]  40.01M  24.9MB/s

# %% [markdown]
# # **每次启动需要执行**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/sd/stable-diffusion-webui/
# !pip install -r requirements_versions.txt

# 下面有个buxxx的冲突，暂时忽略
# %cd /content/gdrive/MyDrive/sd/stable-diffusion-webui/
# !pip install -r requirements.txt
# Out:
# /content/gdrive/MyDrive/sd/stable-diffusion-webui
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting blendmodes==2022
#   Downloading blendmodes-2022-py3-none-any.whl (10 kB)
# Collecting transformers==4.25.1
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 23.0 MB/s eta 0:00:00
# Collecting accelerate==0.12.0
#   Downloading accelerate-0.12.0-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.0/144.0 KB 15.6 MB/s eta 0:00:00
# Collecting basicsr==1.4.2
#   Downloading basicsr-1.4.2.tar.gz (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 KB 17.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting gfpgan==1.3.8
#   Downloading gfpgan-1.3.8-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.2/52.2 KB 6.6 MB/s eta 0:00:00
# Collecting gradio==3.16.2
#   Downloading gradio-3.16.2-py3-none-any.whl (14.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.2/14.2 MB 69.0 MB/s eta 0:00:00
# Collecting numpy==1.23.3
#   Downloading numpy-1.23.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 27.1 MB/s eta 0:00:00
# Collecting Pillow==9.4.0
#   Downloading Pillow-9.4.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 95.1 MB/s eta 0:00:00
# Collecting realesrgan==0.3.0
#   Downloading realesrgan-0.3.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from -r requirements_versions.txt (line 10)) (1.13.1+cu116)
# Collecting omegaconf==2.2.3
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.3/79.3 KB 11.6 MB/s eta 0:00:00
# Collecting pytorch_lightning==1.7.6
#   Downloading pytorch_lightning-1.7.6-py3-none-any.whl (707 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 707.5/707.5 KB 61.7 MB/s eta 0:00:00
# Collecting scikit-image==0.19.2
#   Downloading scikit_image-0.19.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 99.0 MB/s eta 0:00:00
# Collecting fonts
#   Downloading fonts-0.0.3-py3-none-any.whl (4.2 kB)
# Collecting font-roboto
#   Downloading font-roboto-0.0.1.tar.gz (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 92.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting timm==0.6.7
#   Downloading timm-0.6.7-py3-none-any.whl (509 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.0/510.0 KB 39.6 MB/s eta 0:00:00
# Collecting piexif==1.1.3
#   Downloading piexif-1.1.3-py2.py3-none-any.whl (20 kB)
# Collecting einops==0.4.1
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Collecting jsonmerge==1.8.0
#   Downloading jsonmerge-1.8.0.tar.gz (26 kB)
#   Preparing metadata (setup.py) ... done
# Collecting clean-fid==0.1.29
#   Downloading clean_fid-0.1.29-py3-none-any.whl (24 kB)
# Collecting resize-right==0.0.2
#   Downloading resize_right-0.0.2-py3-none-any.whl (8.9 kB)
# Collecting torchdiffeq==0.2.3
#   Downloading torchdiffeq-0.2.3-py3-none-any.whl (31 kB)
# Collecting kornia==0.6.7
#   Downloading kornia-0.6.7-py2.py3-none-any.whl (565 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 565.1/565.1 KB 52.2 MB/s eta 0:00:00
# Collecting lark==1.1.2
#   Downloading lark-1.1.2-py2.py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.7/104.7 KB 14.5 MB/s eta 0:00:00
# Collecting inflection==0.5.1
#   Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Collecting GitPython==3.1.27
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.2/181.2 KB 25.5 MB/s eta 0:00:00
# Collecting torchsde==0.2.5
#   Downloading torchsde-0.2.5-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 9.0 MB/s eta 0:00:00
# Collecting safetensors==0.2.7
#   Downloading safetensors-0.2.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 73.1 MB/s eta 0:00:00
# Collecting httpcore<=0.15
#   Downloading httpcore-0.15.0-py3-none-any.whl (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 KB 10.3 MB/s eta 0:00:00
# Collecting fastapi==0.90.1
#   Downloading fastapi-0.90.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 KB 7.5 MB/s eta 0:00:00
# Collecting aenum<4,>=3.1.7
#   Downloading aenum-3.1.11-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.5/131.5 KB 18.0 MB/s eta 0:00:00
# Collecting deprecation<3,>=2.1.0
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements_versions.txt (line 2)) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements_versions.txt (line 2)) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements_versions.txt (line 2)) (23.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.13.2-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 23.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements_versions.txt (line 2)) (2.27.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements_versions.txt (line 2)) (4.65.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements_versions.txt (line 2)) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 114.0 MB/s eta 0:00:00
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from accelerate==0.12.0->-r requirements_versions.txt (line 3)) (5.9.4)
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from basicsr==1.4.2->-r requirements_versions.txt (line 4)) (0.18.3)
# Collecting lmdb
#   Downloading lmdb-1.4.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (305 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.9/305.9 KB 33.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from basicsr==1.4.2->-r requirements_versions.txt (line 4)) (4.6.0.66)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from basicsr==1.4.2->-r requirements_versions.txt (line 4)) (1.10.1)
# Collecting tb-nightly
#   Downloading tb_nightly-2.13.0a20230317-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 82.3 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from basicsr==1.4.2->-r requirements_versions.txt (line 4)) (0.14.1+cu116)
# Collecting yapf
#   Downloading yapf-0.32.0-py2.py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.2/190.2 KB 18.1 MB/s eta 0:00:00
# Collecting facexlib>=0.2.5
#   Downloading facexlib-0.2.5-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 KB 9.1 MB/s eta 0:00:00
# Collecting aiofiles
#   Downloading aiofiles-23.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements_versions.txt (line 6)) (4.5.0)
# Collecting markdown-it-py[linkify,plugins]
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements_versions.txt (line 6)) (3.7.1)
# Collecting orjson
#   Downloading orjson-3.8.7-cp39-cp39-manylinux_2_28_x86_64.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.9/140.9 KB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements_versions.txt (line 6)) (1.4.4)
# Collecting python-multipart
#   Downloading python_multipart-0.0.6-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 5.5 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 74.4 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.23.3-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 11.0 MB/s eta 0:00:00
# Collecting uvicorn
#   Downloading uvicorn-0.21.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 KB 8.7 MB/s eta 0:00:00
# Collecting ffmpy
#   Downloading ffmpy-0.3.0.tar.gz (4.8 kB)
#   Preparing metadata (setup.py) ... done
# Collecting websockets>=10.0
#   Downloading websockets-10.4-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 13.8 MB/s eta 0:00:00
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements_versions.txt (line 6)) (4.2.2)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements_versions.txt (line 6)) (2.1.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements_versions.txt (line 6)) (1.10.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements_versions.txt (line 6)) (3.1.2)
# Collecting pycryptodome
#   Downloading pycryptodome-3.17-cp35-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 93.1 MB/s eta 0:00:00
# Collecting pydub
#   Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements_versions.txt (line 6)) (2023.3.0)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 KB 16.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (2.11.2)
# Collecting pyDeprecate>=0.3.1
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 KB 38.8 MB/s eta 0:00:00
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image==0.19.2->-r requirements_versions.txt (line 13)) (1.4.1)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image==0.19.2->-r requirements_versions.txt (line 13)) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image==0.19.2->-r requirements_versions.txt (line 13)) (2023.3.15)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image==0.19.2->-r requirements_versions.txt (line 13)) (3.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.9/dist-packages (from jsonmerge==1.8.0->-r requirements_versions.txt (line 19)) (4.3.3)
# Collecting requests
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 KB 8.6 MB/s eta 0:00:00
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 7.5 MB/s eta 0:00:00
# Collecting boltons>=20.2.1
#   Downloading boltons-23.0.0-py2.py3-none-any.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 KB 26.1 MB/s eta 0:00:00
# Collecting trampoline>=0.1.2
#   Downloading trampoline-0.1.2-py3-none-any.whl (5.2 kB)
# Collecting starlette<0.24.0,>=0.22.0
#   Downloading starlette-0.23.1-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.5/64.5 KB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.25.1->-r requirements_versions.txt (line 2)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers==4.25.1->-r requirements_versions.txt (line 2)) (2022.12.7)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/lib/python3/dist-packages (from requests->transformers==4.25.1->-r requirements_versions.txt (line 2)) (3.0.4)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 8.7 MB/s eta 0:00:00
# Collecting anyio==3.*
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 KB 9.9 MB/s eta 0:00:00
# Collecting sniffio==1.*
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 KB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio==3.16.2->-r requirements_versions.txt (line 6)) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio==3.16.2->-r requirements_versions.txt (line 6)) (0.12.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from facexlib>=0.2.5->gfpgan==1.3.8->-r requirements_versions.txt (line 5)) (0.56.4)
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.0/178.0 KB 24.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio==3.16.2->-r requirements_versions.txt (line 6)) (22.2.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (264 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 26.3 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio==3.16.2->-r requirements_versions.txt (line 6)) (2.0.12)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 20.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->jsonmerge==1.8.0->-r requirements_versions.txt (line 19)) (0.19.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio==3.16.2->-r requirements_versions.txt (line 6)) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio==3.16.2->-r requirements_versions.txt (line 6)) (2.8.2)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (3.19.6)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (1.51.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (1.4.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (2.2.3)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (0.40.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (2.16.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (63.4.3)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting linkify-it-py<3,>=1
#   Downloading linkify_it_py-2.0.0-py3-none-any.whl (19 kB)
# Collecting mdit-py-plugins
#   Downloading mdit_py_plugins-0.3.5-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements_versions.txt (line 6)) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements_versions.txt (line 6)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements_versions.txt (line 6)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements_versions.txt (line 6)) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements_versions.txt (line 6)) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements_versions.txt (line 6)) (4.39.0)
# Collecting tb-nightly
#   Downloading tb_nightly-2.13.0a20230316-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 39.4 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230315-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 96.0 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230314-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 110.1 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230313-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 109.0 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230312-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 113.9 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230311-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 101.9 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230310-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 106.2 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230309-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 110.8 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230308-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 101.1 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230307-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 103.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230306-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 82.1 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230305-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 76.6 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230304-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 88.6 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230303-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 80.7 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230302-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 79.3 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230301-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 84.7 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230228-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 77.1 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230226-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 71.3 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230225-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 58.6 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230224-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 29.8 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230223-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 80.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230221-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 75.2 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230220-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 71.9 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230219-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 77.1 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230218-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 84.6 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230217-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 32.6 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230215-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 86.7 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230214-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 68.0 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230213-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 84.0 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230212-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 77.0 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230211-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 82.4 MB/s eta 0:00:00
#   Downloading tb_nightly-2.13.0a20230210-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 69.8 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230209-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 76.1 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230207-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 115.2 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230206-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 10.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230205-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 114.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230204-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 119.8 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230203-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 122.8 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230202-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 119.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230201-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 116.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230131-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 104.1 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230130-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 114.6 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230129-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 104.7 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230128-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 93.6 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230127-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 113.5 MB/s eta 0:00:00
#   Downloading tb_nightly-2.12.0a20230126-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 118.1 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from uvicorn->gradio==3.16.2->-r requirements_versions.txt (line 6)) (8.1.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (5.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (1.15.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (1.3.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->gradio==3.16.2->-r requirements_versions.txt (line 6)) (3.15.0)
# Collecting uc-micro-py
#   Downloading uc_micro_py-1.0.1-py3-none-any.whl (6.2 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (6.0.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->facexlib>=0.2.5->gfpgan==1.3.8->-r requirements_versions.txt (line 5)) (0.39.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch_lightning==1.7.6->-r requirements_versions.txt (line 12)) (3.2.2)
# Building wheels for collected packages: basicsr, jsonmerge, antlr4-python3-runtime, font-roboto, ffmpy, filterpy
#   Building wheel for basicsr (setup.py) ... done
#   Created wheel for basicsr: filename=basicsr-1.4.2-py3-none-any.whl size=214839 sha256=46967ae5f6bf1d81e3fc55b3e4c832ed54bf90167f324feaaca303c77adf6a9b
#   Stored in directory: /root/.cache/pip/wheels/42/d6/3d/6d8c4b8fabeb93dd442eb255f133e8928c75d903fe20e9472c
#   Building wheel for jsonmerge (setup.py) ... done
#   Created wheel for jsonmerge: filename=jsonmerge-1.8.0-py3-none-any.whl size=18001 sha256=c5cc03cafe50bed6f05c87c08c3600164df4a7ae6a9ea6a2d8f3dcde7cf4f6a2
#   Stored in directory: /root/.cache/pip/wheels/03/14/12/5cdea1df387d310e33c903405b62a79f3fb1f2d26ad38bf11f
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144573 sha256=9c52938799aab804a2c0f5f2184c13e53d73528fe2233d4b407815f5fe929f4b
#   Stored in directory: /root/.cache/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
#   Building wheel for font-roboto (setup.py) ... done
#   Created wheel for font-roboto: filename=font_roboto-0.0.1-py3-none-any.whl size=2359752 sha256=24a5e9d7845b9eedf364a73fc1ac8f1abb2e7be8ecda9f4965fe33a8082366a6
#   Stored in directory: /root/.cache/pip/wheels/26/36/01/d5840af8f7419a9361142426ff7709b529f8e3624ae2248c68
#   Building wheel for ffmpy (setup.py) ... done
#   Created wheel for ffmpy: filename=ffmpy-0.3.0-py3-none-any.whl size=4707 sha256=bea97989e36853c1c1c5023354c6d88d61375e60817d61868c2eb2f5ab27e961
#   Stored in directory: /root/.cache/pip/wheels/91/e2/96/f676aa08bfd789328c6576cd0f1fde4a3d686703bb0c247697
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110473 sha256=f1d0c28bdd286beeaa14fb39f16fd928fe2102def83ca3febccb146bd813a651
#   Stored in directory: /root/.cache/pip/wheels/53/e6/de/a09ea01e923aaf88b9f8c7c44329e857b2c1a31901167e55e6
# Successfully built basicsr jsonmerge antlr4-python3-runtime font-roboto ffmpy filterpy
# Installing collected packages: yapf, trampoline, tokenizers, safetensors, rfc3986, resize-right, pydub, lmdb, lark, fonts, font-roboto, ffmpy, einops, boltons, antlr4-python3-runtime, aenum, addict, websockets, uc-micro-py, sniffio, smmap, python-multipart, pyDeprecate, pycryptodome, Pillow, piexif, orjson, omegaconf, numpy, multidict, mdurl, inflection, idna, h11, frozenlist, deprecation, async-timeout, aiofiles, yarl, uvicorn, torchmetrics, requests, markdown-it-py, linkify-it-py, kornia, jsonmerge, gitdb, blendmodes, anyio, aiosignal, accelerate, torchsde, torchdiffeq, starlette, scikit-image, mdit-py-plugins, huggingface-hub, httpcore, GitPython, aiohttp, transformers, timm, httpx, filterpy, fastapi, clean-fid, tb-nightly, gradio, facexlib, pytorch_lightning, basicsr, gfpgan, realesrgan
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 8.4.0
#     Uninstalling Pillow-8.4.0:
#       Successfully uninstalled Pillow-8.4.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.19.3
#     Uninstalling scikit-image-0.19.3:
#       Successfully uninstalled scikit-image-0.19.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tweepy 4.13.0 requires requests<3,>=2.27.0, but you have requests 2.25.1 which is incompatible.
# google-colab 1.0.0 requires requests>=2.27.0, but you have requests 2.25.1 which is incompatible.
# Successfully installed GitPython-3.1.27 Pillow-9.4.0 accelerate-0.12.0 addict-2.4.0 aenum-3.1.11 aiofiles-23.1.0 aiohttp-3.8.4 aiosignal-1.3.1 antlr4-python3-runtime-4.9.3 anyio-3.6.2 async-timeout-4.0.2 basicsr-1.4.2 blendmodes-2022 boltons-23.0.0 clean-fid-0.1.29 deprecation-2.1.0 einops-0.4.1 facexlib-0.2.5 fastapi-0.90.1 ffmpy-0.3.0 filterpy-1.4.5 font-roboto-0.0.1 fonts-0.0.3 frozenlist-1.3.3 gfpgan-1.3.8 gitdb-4.0.10 gradio-3.16.2 h11-0.12.0 httpcore-0.15.0 httpx-0.23.3 huggingface-hub-0.13.2 idna-2.10 inflection-0.5.1 jsonmerge-1.8.0 kornia-0.6.7 lark-1.1.2 linkify-it-py-2.0.0 lmdb-1.4.0 markdown-it-py-2.2.0 mdit-py-plugins-0.3.5 mdurl-0.1.2 multidict-6.0.4 numpy-1.23.3 omegaconf-2.2.3 orjson-3.8.7 piexif-1.1.3 pyDeprecate-0.3.2 pycryptodome-3.17 pydub-0.25.1 python-multipart-0.0.6 pytorch_lightning-1.7.6 realesrgan-0.3.0 requests-2.25.1 resize-right-0.0.2 rfc3986-1.5.0 safetensors-0.2.7 scikit-image-0.19.2 smmap-5.0.0 sniffio-1.3.0 starlette-0.23.1 tb-nightly-2.12.0a20230126 timm-0.6.7 tokenizers-0.13.2 torchdiffeq-0.2.3 torchmetrics-0.11.4 torchsde-0.2.5 trampoline-0.1.2 transformers-4.25.1 uc-micro-py-1.0.1 uvicorn-0.21.1 websockets-10.4 yapf-0.32.0 yarl-1.8.2
# /content/gdrive/MyDrive/sd/stable-diffusion-webui
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: blendmodes in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 1)) (2022)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 2)) (0.12.0)
# Requirement already satisfied: basicsr in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 3)) (1.4.2)
# Requirement already satisfied: fonts in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 4)) (0.0.3)
# Requirement already satisfied: font-roboto in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 5)) (0.0.1)
# Requirement already satisfied: gfpgan in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 6)) (1.3.8)
# Requirement already satisfied: gradio==3.16.2 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 7)) (3.16.2)
# Collecting invisible-watermark
#   Downloading invisible_watermark-0.1.5-py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 9)) (1.23.3)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 10)) (2.2.3)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 11)) (4.6.0.66)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 12)) (2.25.1)
# Requirement already satisfied: piexif in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 13)) (1.1.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 14)) (9.4.0)
# Collecting pytorch_lightning==1.7.7
#   Downloading pytorch_lightning-1.7.7-py3-none-any.whl (708 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 708.1/708.1 KB 51.6 MB/s eta 0:00:00
# Requirement already satisfied: realesrgan in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: scikit-image>=0.19 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 17)) (0.19.2)
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 KB 35.6 MB/s eta 0:00:00
# Requirement already satisfied: transformers==4.25.1 in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 19)) (4.25.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 20)) (1.13.1+cu116)
# Requirement already satisfied: einops in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 21)) (0.4.1)
# Requirement already satisfied: jsonmerge in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 22)) (1.8.0)
# Requirement already satisfied: clean-fid in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 23)) (0.1.29)
# Requirement already satisfied: resize-right in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 24)) (0.0.2)
# Requirement already satisfied: torchdiffeq in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 25)) (0.2.3)
# Requirement already satisfied: kornia in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 26)) (0.6.7)
# Requirement already satisfied: lark in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 27)) (1.1.2)
# Requirement already satisfied: inflection in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 28)) (0.5.1)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 29)) (3.1.27)
# Requirement already satisfied: torchsde in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 30)) (0.2.5)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 31)) (0.2.7)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from -r requirements.txt (line 32)) (5.9.4)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (23.1.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: httpx in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (0.23.3)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (10.4)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (2.1.2)
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (4.2.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (1.10.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (4.5.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (6.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (0.21.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (2023.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (3.8.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (3.1.2)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (3.17)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: markdown-it-py[linkify,plugins] in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (2.2.0)
# Requirement already satisfied: orjson in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (3.8.7)
# Requirement already satisfied: pydub in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (0.0.6)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (0.90.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from gradio==3.16.2->-r requirements.txt (line 7)) (3.7.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.11.4)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.3.2)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (4.65.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (23.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.9/dist-packages (from pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (2.11.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from timm==0.4.12->-r requirements.txt (line 18)) (0.14.1+cu116)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements.txt (line 19)) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements.txt (line 19)) (2022.10.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements.txt (line 19)) (3.10.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.9/dist-packages (from transformers==4.25.1->-r requirements.txt (line 19)) (0.13.2)
# Requirement already satisfied: deprecation<3,>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from blendmodes->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: aenum<4,>=3.1.7 in /usr/local/lib/python3.9/dist-packages (from blendmodes->-r requirements.txt (line 1)) (3.1.11)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (1.10.1)
# Requirement already satisfied: addict in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (2.4.0)
# Requirement already satisfied: tb-nightly in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (2.12.0a20230126)
# Requirement already satisfied: yapf in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (0.32.0)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (4.6.0.66)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from basicsr->-r requirements.txt (line 3)) (0.18.3)
# Requirement already satisfied: facexlib>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from gfpgan->-r requirements.txt (line 6)) (0.2.5)
# Collecting onnx
#   Downloading onnx-1.13.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 71.3 MB/s eta 0:00:00
# Collecting onnxruntime
#   Downloading onnxruntime-1.14.1-cp39-cp39-manylinux_2_27_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 68.3 MB/s eta 0:00:00
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from invisible-watermark->-r requirements.txt (line 8)) (1.4.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.9/dist-packages (from omegaconf->-r requirements.txt (line 10)) (4.9.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->-r requirements.txt (line 12)) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->-r requirements.txt (line 12)) (1.26.15)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/lib/python3/dist-packages (from requests->-r requirements.txt (line 12)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->-r requirements.txt (line 12)) (2022.12.7)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.19->-r requirements.txt (line 17)) (3.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.19->-r requirements.txt (line 17)) (2023.3.15)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.9/dist-packages (from scikit-image>=0.19->-r requirements.txt (line 17)) (2.9.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.9/dist-packages (from jsonmerge->-r requirements.txt (line 22)) (4.3.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from GitPython->-r requirements.txt (line 29)) (4.0.10)
# Requirement already satisfied: trampoline>=0.1.2 in /usr/local/lib/python3.9/dist-packages (from torchsde->-r requirements.txt (line 30)) (0.1.2)
# Requirement already satisfied: boltons>=20.2.1 in /usr/local/lib/python3.9/dist-packages (from torchsde->-r requirements.txt (line 30)) (23.0.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio==3.16.2->-r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from altair>=4.2.0->gradio==3.16.2->-r requirements.txt (line 7)) (0.4)
# Requirement already satisfied: filterpy in /usr/local/lib/python3.9/dist-packages (from facexlib>=0.2.5->gfpgan->-r requirements.txt (line 6)) (1.4.5)
# Requirement already satisfied: numba in /usr/local/lib/python3.9/dist-packages (from facexlib>=0.2.5->gfpgan->-r requirements.txt (line 6)) (0.56.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio==3.16.2->-r requirements.txt (line 7)) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio==3.16.2->-r requirements.txt (line 7)) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio==3.16.2->-r requirements.txt (line 7)) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio==3.16.2->-r requirements.txt (line 7)) (1.8.2)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio==3.16.2->-r requirements.txt (line 7)) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio==3.16.2->-r requirements.txt (line 7)) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->gradio==3.16.2->-r requirements.txt (line 7)) (22.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->GitPython->-r requirements.txt (line 29)) (5.0.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from jsonschema->jsonmerge->-r requirements.txt (line 22)) (0.19.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio==3.16.2->-r requirements.txt (line 7)) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas->gradio==3.16.2->-r requirements.txt (line 7)) (2.8.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (2.16.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (2.2.3)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.51.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (63.4.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.4.0)
# Requirement already satisfied: protobuf<4,>=3.9.2 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (3.19.6)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (3.4.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.40.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.4.6)
# Requirement already satisfied: starlette<0.24.0,>=0.22.0 in /usr/local/lib/python3.9/dist-packages (from fastapi->gradio==3.16.2->-r requirements.txt (line 7)) (0.23.1)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.9/dist-packages (from httpx->gradio==3.16.2->-r requirements.txt (line 7)) (1.3.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from httpx->gradio==3.16.2->-r requirements.txt (line 7)) (0.15.0)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /usr/local/lib/python3.9/dist-packages (from httpx->gradio==3.16.2->-r requirements.txt (line 7)) (1.5.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify,plugins]->gradio==3.16.2->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify,plugins]->gradio==3.16.2->-r requirements.txt (line 7)) (0.3.5)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.9/dist-packages (from markdown-it-py[linkify,plugins]->gradio==3.16.2->-r requirements.txt (line 7)) (2.0.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements.txt (line 7)) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements.txt (line 7)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements.txt (line 7)) (4.39.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements.txt (line 7)) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements.txt (line 7)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->gradio==3.16.2->-r requirements.txt (line 7)) (3.0.9)
# Collecting protobuf<4,>=3.9.2
#   Downloading protobuf-3.20.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 71.0 MB/s eta 0:00:00
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from onnxruntime->invisible-watermark->-r requirements.txt (line 8)) (1.11.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.9/dist-packages (from onnxruntime->invisible-watermark->-r requirements.txt (line 8)) (23.3.3)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 KB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.9/dist-packages (from uvicorn->gradio==3.16.2->-r requirements.txt (line 7)) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.9/dist-packages (from uvicorn->gradio==3.16.2->-r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (4.9)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (1.3.1)
# Requirement already satisfied: anyio==3.* in /usr/local/lib/python3.9/dist-packages (from httpcore<0.17.0,>=0.15.0->httpx->gradio==3.16.2->-r requirements.txt (line 7)) (3.6.2)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->gradio==3.16.2->-r requirements.txt (line 7)) (3.15.0)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.9/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify,plugins]->gradio==3.16.2->-r requirements.txt (line 7)) (1.0.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (6.0.0)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 KB 12.1 MB/s eta 0:00:00
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba->facexlib>=0.2.5->gfpgan->-r requirements.txt (line 6)) (0.39.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->onnxruntime->invisible-watermark->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch_lightning==1.7.7->-r requirements.txt (line 15)) (3.2.2)
# Installing collected packages: protobuf, humanfriendly, onnx, coloredlogs, timm, onnxruntime, invisible-watermark, pytorch_lightning
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: timm
#     Found existing installation: timm 0.6.7
#     Uninstalling timm-0.6.7:
#       Successfully uninstalled timm-0.6.7
#   Attempting uninstall: pytorch_lightning
#     Found existing installation: pytorch-lightning 1.7.6
#     Uninstalling pytorch-lightning-1.7.6:
#       Successfully uninstalled pytorch-lightning-1.7.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed coloredlogs-15.0.1 humanfriendly-10.0 invisible-watermark-0.1.5 onnx-1.13.1 onnxruntime-1.14.1 protobuf-3.20.3 pytorch_lightning-1.7.7 timm-0.4.12

# %%
# !pip install open_clip_torch
# !pip install clip
# !pip install xformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting open_clip_torch
#   Downloading open_clip_torch-2.16.0-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 26.7 MB/s eta 0:00:00
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from open_clip_torch) (2022.10.31)
# Requirement already satisfied: protobuf<4 in /usr/local/lib/python3.9/dist-packages (from open_clip_torch) (3.20.3)
# Requirement already satisfied: timm in /usr/local/lib/python3.9/dist-packages (from open_clip_torch) (0.4.12)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from open_clip_torch) (4.65.0)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 57.0 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.9/dist-packages (from open_clip_torch) (0.13.2)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 KB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from open_clip_torch) (0.14.1+cu116)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.9/dist-packages (from open_clip_torch) (1.13.1+cu116)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.9.0->open_clip_torch) (4.5.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->open_clip_torch) (0.2.6)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub->open_clip_torch) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub->open_clip_torch) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub->open_clip_torch) (2.25.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub->open_clip_torch) (3.10.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->open_clip_torch) (9.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision->open_clip_torch) (1.23.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/lib/python3/dist-packages (from requests->huggingface-hub->open_clip_torch) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub->open_clip_torch) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub->open_clip_torch) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub->open_clip_torch) (1.26.15)
# Installing collected packages: sentencepiece, ftfy, open_clip_torch
# Successfully installed ftfy-6.1.1 open_clip_torch-2.16.0 sentencepiece-0.1.97
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting clip
#   Downloading clip-0.2.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-0.2.0-py3-none-any.whl size=7005 sha256=4ce7ed6def655ec5f43a2e6e0cca2387f8f5e2380b489f91bdb6ce8e7704f67e
#   Stored in directory: /root/.cache/pip/wheels/8f/99/44/ceb6f1b57fd1a1d7241d886a4074ffbd552937ed87ccf479d6
# Successfully built clip
# Installing collected packages: clip
# Successfully installed clip-0.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting xformers
#   Downloading xformers-0.0.16-cp39-cp39-manylinux2014_x86_64.whl (50.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 MB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: torch==1.13.1 in /usr/local/lib/python3.9/dist-packages (from xformers) (1.13.1+cu116)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from xformers) (1.23.3)
# Collecting pyre-extensions==0.0.23
#   Downloading pyre_extensions-0.0.23-py3-none-any.whl (11 kB)
# Collecting typing-inspect
#   Downloading typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from pyre-extensions==0.0.23->xformers) (4.5.0)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, typing-inspect, pyre-extensions, xformers
# Successfully installed mypy-extensions-1.0.0 pyre-extensions-0.0.23 typing-inspect-0.8.0 xformers-0.0.16

# %%
#@markdown # Start Stable-Diffusion
from IPython.utils import capture
import time
import sys
import os
import fileinput

Use_localtunnel = False #@param {type:"boolean"}

User = "" #@param {type:"string"}
Password= "" #@param {type:"string"}
#@markdown - Add credentials to your Gradio interface (optional).

auth=f"--gradio-auth {User}:{Password}"
if User =="" or Password=="":
  auth=""

with capture.capture_output() as cap:
  if not os.path.exists('/tools/node/bin/lt'):
    # !npm install -g localtunnel

with capture.capture_output() as cap:
  # %cd /content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/
  # !wget -O paths.py https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/AUTOMATIC1111_files/paths.py
  # !wget -O extras.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-webui/master/modules/extras.py
  # !wget -O sd_models.py https://raw.githubusercontent.com/AUTOMATIC1111/stable-diffusion-webui/master/modules/sd_models.py
  # !wget -q -O /usr/local/lib/python3.8/dist-packages/gradio/blocks.py https://raw.githubusercontent.com/TheLastBen/fast-stable-diffusion/main/AUTOMATIC1111_files/blocks.py
  # %cd /content/gdrive/MyDrive/sd/stable-diffusion-webui/

  # !sed -i "s@os.path.splitext(checkpoint_file)@os.path.splitext(checkpoint_file); map_location='cuda'@" /content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/sd_models.py
  # !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' /content/gdrive/MyDrive/sd/stable-diffusion-webui/webui.py
  # !sed -i "s@map_location='cpu'@map_location='cuda'@" /content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/extras.py

share=''
if not Use_localtunnel:
  share='--share'

else:
  with capture.capture_output() as cap:
    share=''
    # %cd /content
    # !nohup lt --port 7860 > srv.txt 2>&1 &
    time.sleep(2)
    # !grep -o 'https[^ ]*' /content/srv.txt >srvr.txt
    time.sleep(2)
    srv= getoutput('cat /content/srvr.txt')

    for line in fileinput.input('/usr/local/lib/python3.8/dist-packages/gradio/blocks.py', inplace=True):
      if line.strip().startswith('self.server_name ='):
          line = f'            self.server_name = "{srv[8:]}"\n'
      if line.strip().startswith('self.protocol = "https"'):
          line = '            self.protocol = "https"\n'
      if line.strip().startswith('if self.local_url.startswith("https") or self.is_colab'):
          line = ''
      if line.strip().startswith('else "http"'):
          line = ''
      sys.stdout.write(line)
            
    # !rm /content/srv.txt /content/srvr.txt
    # %cd /content/gdrive/MyDrive/sd/stable-diffusion-webui

try:
  model
  if os.path.isfile(model):
    # !python /content/gdrive/MyDrive/sd/stable-diffusion-webui/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt "$model" --xformers $auth --disable-console-progressbars
  else:
    # !python /content/gdrive/MyDrive/sd/stable-diffusion-webui/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae  --ckpt-dir "$model" --xformers $auth --disable-console-progressbars
except:
   # !python /content/gdrive/MyDrive/sd/stable-diffusion-webui/webui.py $share --api --disable-safe-unpickle --enable-insecure-extension-access --no-download-sd-model --no-half-vae --xformers $auth --disable-console-progressbars
# Out:
# 2023-03-18 14:29:36.441412: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-03-18 14:29:40.033006: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-18 14:29:40.033251: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib/python3.9/dist-packages/cv2/../../lib64:/usr/lib64-nvidia
# 2023-03-18 14:29:40.033278: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# [AddNet] Updating model hashes...
# 0it [00:00, ?it/s]
# [AddNet] Updating model hashes...
# 0it [00:00, ?it/s]
# Loading weights [812cd9f9d9] from /content/gdrive/MyDrive/sd/stable-diffusion-webui/models/Stable-diffusion/anythingV3_fp16.ckpt
# Creating model from config: /content/gdrive/MyDrive/sd/stable-diffusion-webui/configs/v1-inference.yaml
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Applying xformers cross attention optimization.
# Textual inversion embeddings loaded(1): ulzzang
# Model loaded in 48.8s (load weights from disk: 42.8s, create model: 1.4s, apply weights to model: 2.8s, apply half(): 1.0s, move model to device: 0.6s).
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://020605f8-5c15-4cbc.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# Error running process: /content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/scripts.py", line 386, in process
#     script.process(p, *script_args)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 650, in process
#     model_net = self.load_control_model(p, unet, unit.model, unit.low_vram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 457, in load_control_model
#     model_net = self.build_control_model(p, unet, model, lowvram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 468, in build_control_model
#     raise RuntimeError(f"model not found: {model}")
# RuntimeError: model not found: None
#
# 100% 20/20 [00:10<00:00,  1.96it/s]
# Error running process: /content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/scripts.py", line 386, in process
#     script.process(p, *script_args)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 650, in process
#     model_net = self.load_control_model(p, unet, unit.model, unit.low_vram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 457, in load_control_model
#     model_net = self.build_control_model(p, unet, model, lowvram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 468, in build_control_model
#     raise RuntimeError(f"model not found: {model}")
# RuntimeError: model not found: None
#
# 100% 45/45 [00:11<00:00,  3.95it/s]
# Error running process: /content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/scripts.py", line 386, in process
#     script.process(p, *script_args)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 650, in process
#     model_net = self.load_control_model(p, unet, unit.model, unit.low_vram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 457, in load_control_model
#     model_net = self.build_control_model(p, unet, model, lowvram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 468, in build_control_model
#     raise RuntimeError(f"model not found: {model}")
# RuntimeError: model not found: None
#
# 100% 45/45 [00:08<00:00,  5.34it/s]
# 100% 45/45 [00:08<00:00,  5.34it/s]
# Error running process: /content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/scripts.py", line 386, in process
#     script.process(p, *script_args)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 650, in process
#     model_net = self.load_control_model(p, unet, unit.model, unit.low_vram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 457, in load_control_model
#     model_net = self.build_control_model(p, unet, model, lowvram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 468, in build_control_model
#     raise RuntimeError(f"model not found: {model}")
# RuntimeError: model not found: None
#
# 100% 45/45 [00:08<00:00,  5.40it/s]
# 100% 45/45 [00:08<00:00,  5.40it/s]
# Error running process: /content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/scripts.py", line 386, in process
#     script.process(p, *script_args)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 650, in process
#     model_net = self.load_control_model(p, unet, unit.model, unit.low_vram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 457, in load_control_model
#     model_net = self.build_control_model(p, unet, model, lowvram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 468, in build_control_model
#     raise RuntimeError(f"model not found: {model}")
# RuntimeError: model not found: None
#
# 100% 45/45 [00:08<00:00,  5.36it/s]
# 100% 45/45 [00:08<00:00,  5.35it/s]
# Error running process: /content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py
# Traceback (most recent call last):
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/modules/scripts.py", line 386, in process
#     script.process(p, *script_args)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 650, in process
#     model_net = self.load_control_model(p, unet, unit.model, unit.low_vram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 457, in load_control_model
#     model_net = self.build_control_model(p, unet, model, lowvram)
#   File "/content/gdrive/MyDrive/sd/stable-diffusion-webui/extensions/sd-webui-controlnet/scripts/controlnet.py", line 468, in build_control_model
#     raise RuntimeError(f"model not found: {model}")
# RuntimeError: model not found: None
#
# 100% 45/45 [00:08<00:00,  5.35it/s]
# 100% 45/45 [00:08<00:00,  5.37it/s]
# Interrupted with signal 2 in <frame at 0x69e88d50, file '/content/gdrive/MyDrive/sd/stable-diffusion-webui/webui.py', line 173, code wait_on_server>
